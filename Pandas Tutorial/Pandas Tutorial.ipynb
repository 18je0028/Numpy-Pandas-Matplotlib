# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name" : ["harry", "rohan", "skillf", "shubh"],
    "marks" : [92, 34, 24, 17],
    "city" : ["rampur", "kolkata", "bareily", "antartica"]
}

# %%
df =pd.DataFrame(dict1)

# %%
df
# Out:
#      name  marks       city
# 0   harry     92     rampur
# 1   rohan     34    kolkata
# 2  skillf     24    bareily
# 3   shubh     17  antartica

# %%
# This will make a friends.csv file in you storage file
df.to_csv('friends.csv')

# %%
# What if you don't want to see the index 0, 1, 2, 3
df.to_csv('friends_index_false.csv', index = False)

# %%
# what if you want to see some attribute of the dict1 , then we use head() function
df.head(2)
# Out:
#     name  marks     city
# 0  harry     92   rampur
# 1  rohan     34  kolkata

# %%
# Similarily, tail(k) last k rows dikhayega
df.tail(2)
# Out:
#      name  marks       city
# 2  skillf     24    bareily
# 3   shubh     17  antartica

# %%
# we got describe() function --> (Y sirf numerical data p kaam karta hai)
#to show count, mean, standard deviation, min, max, 25% data kis value se kam hai 50% , 75% data kis value se kam hai
df.describe()
# Out:
#           marks
# count   4.00000
# mean   41.75000
# std    34.21866
# min    17.00000
# 25%    22.25000
# 50%    29.00000
# 75%    48.50000
# max    92.00000

# %%
harry = pd.read_csv('harry.csv')

# %%
harry
# Out:
#    Unnamed: 0  Train No  Speed       City
# 0           0     12322     70     rampur
# 1           1     12534    123    kolkata
# 2           2    125654     67    bareily
# 3           3    564523     87  antartica

# %%
# 2 methods , the 2nd one is efficient
# harry['speed']
harry.loc[ : , 'Speed']
# Out:
# 0     70
# 1    123
# 2     67
# 3     87
# Name: Speed, dtype: int64

# %%
harry['Speed'][0]
# Out:
# 70

# %%
# Y kaam karega but warning dega
# If we want to chage the speed of train number 12322
# harry['Speed'][0] = 70
harry.loc[0, 'Speed'] = 70

# %%
harry
# Out:
#    Unnamed: 0  Train No  Speed       City
# 0           0     12322     70     rampur
# 1           1     12534    123    kolkata
# 2           2    125654     67    bareily
# 3           3    564523     87  antartica

# %%
# If we want to store the changed result of harry, we can store it to our csv file
harry.to_csv('harry.csv')

# %%
# If we want to change the index of harry, then we do
harry.index = ['first', 'second', 'third', 'fourth']

# %%
harry
# Out:
#         Unnamed: 0  Train No  Speed       City
# first            0     12322     70     rampur
# second           1     12534    123    kolkata
# third            2    125654     67    bareily
# fourth           3    564523     87  antartica

# %%
# DataFrame pura msExcel wala table hota hai (isme different types k data aa sakte hai, 1 column pura se int, 1 column pura string, 1 column pura boolean, etc)
# Series hota hai DataFrame k andar koi sa bhi 1 column (isme sirf 1 type ka data aa sakta hai , ex: int,float, string etc )

# %%
ser = pd.Series(np.random.rand(334))
# (by default all values are b/w [0,1)])

# %%
ser
# Out:
# 0      0.476185
# 1      0.713340
# 2      0.866102
# 3      0.215676
# 4      0.024752
#          ...
# 329    0.439646
# 330    0.592874
# 331    0.664574
# 332    0.309988
# 333    0.695252
# Length: 334, dtype: float64

# %%
# Iski type series hai mtlab , ek column
type(ser)
# Out:
# pandas.core.series.Series

# %%
# To create a new dataFrame of 334 rows and 5 columns (by default all values are b/w [0,1)])
newdf = pd.DataFrame(np.random.rand(334,5), index = np.arange(0,334))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0
# 4    0.002714  0.092858  0.635275  0.101599  0.671199
# ..        ...       ...       ...       ...       ...
# 329   0.65033  0.925719  0.660003  0.620706  0.684558
# 330    0.9935  0.269667  0.650373  0.724628  0.950385
# 331  0.444453  0.105023  0.840456  0.848208  0.550511
# 332  0.828512  0.593017  0.420084  0.204303  0.900175
# 333  0.068908  0.709423  0.464158  0.180856  0.270479
#
# [334 rows x 5 columns]

# %%
newdf.head(2)
# Out:
#           A         B         C         D         E
# 0       654  0.627228  0.639423  0.669767  0.823749
# 1  0.322129  0.409836  0.841431  0.727744  0.625058

# %%
# Now, newdf.loc[0, 0] will give error because it has changed to A,B,C,D,E
# ye 1 naya column bana dega
newdf.loc[0,0] = 456

# %%
newdf
# Out:
#             A         B         C         D         E      0
# 0         654  0.627228  0.639423  0.669767  0.823749  456.0
# 1    0.322129  0.409836  0.841431  0.727744  0.625058    NaN
# 2    0.078752  0.108694  0.514754  0.449441  0.141361    NaN
# 3    0.115186  0.443177  0.181930  0.464275  0.173529    NaN
# 4    0.002714  0.092858  0.635275  0.101599  0.671199    NaN
# ..        ...       ...       ...       ...       ...    ...
# 329   0.65033  0.925719  0.660003  0.620706  0.684558    NaN
# 330    0.9935  0.269667  0.650373  0.724628  0.950385    NaN
# 331  0.444453  0.105023  0.840456  0.848208  0.550511    NaN
# 332  0.828512  0.593017  0.420084  0.204303  0.900175    NaN
# 333  0.068908  0.709423  0.464158  0.180856  0.270479    NaN
#
# [334 rows x 6 columns]

# %%
# This will change the result
newdf.loc[0, 'A'] = 45

# %%
newdf
# Out:
#             A         B         C         D         E      0
# 0          45  0.627228  0.639423  0.669767  0.823749  456.0
# 1    0.322129  0.409836  0.841431  0.727744  0.625058    NaN
# 2    0.078752  0.108694  0.514754  0.449441  0.141361    NaN
# 3    0.115186  0.443177  0.181930  0.464275  0.173529    NaN
# 4    0.002714  0.092858  0.635275  0.101599  0.671199    NaN
# ..        ...       ...       ...       ...       ...    ...
# 329   0.65033  0.925719  0.660003  0.620706  0.684558    NaN
# 330    0.9935  0.269667  0.650373  0.724628  0.950385    NaN
# 331  0.444453  0.105023  0.840456  0.848208  0.550511    NaN
# 332  0.828512  0.593017  0.420084  0.204303  0.900175    NaN
# 333  0.068908  0.709423  0.464158  0.180856  0.270479    NaN
#
# [334 rows x 6 columns]

# %%
# To drop a column
newdf.drop(0, axis = 1)
# Out:
#             A         B         C         D         E
# 0          45  0.627228  0.639423  0.669767  0.823749
# 1    0.322129  0.409836  0.841431  0.727744  0.625058
# 2    0.078752  0.108694  0.514754  0.449441  0.141361
# 3    0.115186  0.443177  0.181930  0.464275  0.173529
# 4    0.002714  0.092858  0.635275  0.101599  0.671199
# ..        ...       ...       ...       ...       ...
# 329   0.65033  0.925719  0.660003  0.620706  0.684558
# 330    0.9935  0.269667  0.650373  0.724628  0.950385
# 331  0.444453  0.105023  0.840456  0.848208  0.550511
# 332  0.828512  0.593017  0.420084  0.204303  0.900175
# 333  0.068908  0.709423  0.464158  0.180856  0.270479
#
# [334 rows x 5 columns]

# %%
newdf
# Out:
#             A         B         C         D         E      0
# 0          45  0.627228  0.639423  0.669767  0.823749  456.0
# 1    0.322129  0.409836  0.841431  0.727744  0.625058    NaN
# 2    0.078752  0.108694  0.514754  0.449441  0.141361    NaN
# 3    0.115186  0.443177  0.181930  0.464275  0.173529    NaN
# 4    0.002714  0.092858  0.635275  0.101599  0.671199    NaN
# ..        ...       ...       ...       ...       ...    ...
# 329   0.65033  0.925719  0.660003  0.620706  0.684558    NaN
# 330    0.9935  0.269667  0.650373  0.724628  0.950385    NaN
# 331  0.444453  0.105023  0.840456  0.848208  0.550511    NaN
# 332  0.828512  0.593017  0.420084  0.204303  0.900175    NaN
# 333  0.068908  0.709423  0.464158  0.180856  0.270479    NaN
#
# [334 rows x 6 columns]

# %%
newdf = newdf.drop(0, axis = 1)

# %%
newdf
# Out:
#             A         B         C         D         E
# 0          45  0.627228  0.639423  0.669767  0.823749
# 1    0.322129  0.409836  0.841431  0.727744  0.625058
# 2    0.078752  0.108694  0.514754  0.449441  0.141361
# 3    0.115186  0.443177  0.181930  0.464275  0.173529
# 4    0.002714  0.092858  0.635275  0.101599  0.671199
# ..        ...       ...       ...       ...       ...
# 329   0.65033  0.925719  0.660003  0.620706  0.684558
# 330    0.9935  0.269667  0.650373  0.724628  0.950385
# 331  0.444453  0.105023  0.840456  0.848208  0.550511
# 332  0.828512  0.593017  0.420084  0.204303  0.900175
# 333  0.068908  0.709423  0.464158  0.180856  0.270479
#
# [334 rows x 5 columns]

# %%
# What if we want to see the result of a specific row and columns in DataFrame
newdf.loc[ [1, 2] , ['C', 'D']]
# Out:
#           C         D
# 1  0.841431  0.727744
# 2  0.514754  0.449441

# %%
newdf.loc[ : ,['C', 'D']]
# Out:
#             C         D
# 0    0.639423  0.669767
# 1    0.841431  0.727744
# 2    0.514754  0.449441
# 3    0.181930  0.464275
# 4    0.635275  0.101599
# ..        ...       ...
# 329  0.660003  0.620706
# 330  0.650373  0.724628
# 331  0.840456  0.848208
# 332  0.420084  0.204303
# 333  0.464158  0.180856
#
# [334 rows x 2 columns]

# %%
newdf.loc[ [1, 2], : ]
# Out:
#           A         B         C         D         E
# 1  0.322129  0.409836  0.841431  0.727744  0.625058
# 2  0.078752  0.108694  0.514754  0.449441  0.141361

# %%
newdf.loc[ 0:4 , 'A':'D']
# Out:
#           A         B         C         D
# 0        45  0.627228  0.639423  0.669767
# 1  0.322129  0.409836  0.841431  0.727744
# 2  0.078752  0.108694  0.514754  0.449441
# 3  0.115186  0.443177  0.181930  0.464275
# 4  0.002714  0.092858  0.635275  0.101599

# %%
# We can perform database queries here too

# %%
# Let's say i want to know all the rows where column 'A' value is < 0 .2

# %%
# As we already know , newdf[0] represents a columns here
newdf['A']
# Out:
# 0            45
# 1      0.322129
# 2      0.078752
# 3      0.115186
# 4      0.002714
#          ...
# 329     0.65033
# 330      0.9935
# 331    0.444453
# 332    0.828512
# 333    0.068908
# Name: A, Length: 334, dtype: object

# %%
# dataframe.loc[(condition)]
newdf.loc[ newdf['A'] < 0.2 ]
# Out:
#             A         B         C         D         E
# 2    0.078752  0.108694  0.514754  0.449441  0.141361
# 3    0.115186  0.443177  0.181930  0.464275  0.173529
# 4    0.002714  0.092858  0.635275  0.101599  0.671199
# 7    0.059238  0.914571  0.829711  0.487781  0.996982
# 32   0.009169  0.222999  0.281528  0.801213  0.754406
# ..        ...       ...       ...       ...       ...
# 320  0.164561  0.571654  0.175459  0.338155  0.694273
# 321  0.182103  0.227292  0.984863  0.539748  0.830227
# 323   0.06236  0.807234  0.938137  0.970866  0.475570
# 327  0.043439  0.242566  0.309855  0.053026  0.361709
# 333  0.068908  0.709423  0.464158  0.180856  0.270479
#
# [72 rows x 5 columns]

# %%
newdf.loc[ (newdf['A'] < 0.3) & (newdf['C'] > 0.1)]
# Out:
#             A         B         C         D         E
# 2    0.078752  0.108694  0.514754  0.449441  0.141361
# 3    0.115186  0.443177  0.181930  0.464275  0.173529
# 4    0.002714  0.092858  0.635275  0.101599  0.671199
# 7    0.059238  0.914571  0.829711  0.487781  0.996982
# 11   0.230399  0.473788  0.195114  0.919002  0.625710
# ..        ...       ...       ...       ...       ...
# 320  0.164561  0.571654  0.175459  0.338155  0.694273
# 321  0.182103  0.227292  0.984863  0.539748  0.830227
# 323   0.06236  0.807234  0.938137  0.970866  0.475570
# 327  0.043439  0.242566  0.309855  0.053026  0.361709
# 333  0.068908  0.709423  0.464158  0.180856  0.270479
#
# [94 rows x 5 columns]

# %%
# Agar hame index se ginti karni hai column ki , then iloc use kare
newdf.head()
# Out:
#           A         B         C         D         E
# 0        45  0.627228  0.639423  0.669767  0.823749
# 1  0.322129  0.409836  0.841431  0.727744  0.625058
# 2  0.078752  0.108694  0.514754  0.449441  0.141361
# 3  0.115186  0.443177  0.181930  0.464275  0.173529
# 4  0.002714  0.092858  0.635275  0.101599  0.671199

# %%
newdf.iloc[0, 4]
# Out:
# 0.8237488979427564

# %%
newdf.iloc[0, 4] = 56

# %%
newdf.head()
# Out:
#           A         B         C         D          E
# 0        45  0.627228  0.639423  0.669767  56.000000
# 1  0.322129  0.409836  0.841431  0.727744   0.625058
# 2  0.078752  0.108694  0.514754  0.449441   0.141361
# 3  0.115186  0.443177  0.181930  0.464275   0.173529
# 4  0.002714  0.092858  0.635275  0.101599   0.671199

# %%
newdf.iloc[ [1, 2] , [0, 2]]
# Out:
#           A         C
# 1  0.322129  0.841431
# 2  0.078752  0.514754

# %%
newdf.iloc[ 0:6 , 2: ]
# Out:
#           C         D          E
# 0  0.639423  0.669767  56.000000
# 1  0.841431  0.727744   0.625058
# 2  0.514754  0.449441   0.141361
# 3  0.181930  0.464275   0.173529
# 4  0.635275  0.101599   0.671199
# 5  0.619169  0.869458   0.854780

# %%
newdf.iloc[3:5 , 1:4 ]
# Out:
#           B         C         D
# 3  0.443177  0.181930  0.464275
# 4  0.092858  0.635275  0.101599

# %%
# To drop or erase a row from dataframe
newdf.drop(0)
# Out:
#             A         B         C         D         E
# 1    0.322129  0.409836  0.841431  0.727744  0.625058
# 2    0.078752  0.108694  0.514754  0.449441  0.141361
# 3    0.115186  0.443177  0.181930  0.464275  0.173529
# 4    0.002714  0.092858  0.635275  0.101599  0.671199
# 5     0.63215  0.714490  0.619169  0.869458  0.854780
# ..        ...       ...       ...       ...       ...
# 329   0.65033  0.925719  0.660003  0.620706  0.684558
# 330    0.9935  0.269667  0.650373  0.724628  0.950385
# 331  0.444453  0.105023  0.840456  0.848208  0.550511
# 332  0.828512  0.593017  0.420084  0.204303  0.900175
# 333  0.068908  0.709423  0.464158  0.180856  0.270479
#
# [333 rows x 5 columns]

# %%
# To drop a column from a dataframe
newdf.drop('A', axis = 1)
# Out:
#             B         C         D          E
# 0    0.627228  0.639423  0.669767  56.000000
# 1    0.409836  0.841431  0.727744   0.625058
# 2    0.108694  0.514754  0.449441   0.141361
# 3    0.443177  0.181930  0.464275   0.173529
# 4    0.092858  0.635275  0.101599   0.671199
# ..        ...       ...       ...        ...
# 329  0.925719  0.660003  0.620706   0.684558
# 330  0.269667  0.650373  0.724628   0.950385
# 331  0.105023  0.840456  0.848208   0.550511
# 332  0.593017  0.420084  0.204303   0.900175
# 333  0.709423  0.464158  0.180856   0.270479
#
# [334 rows x 4 columns]

# %%
newdf
# Out:
#             A         B         C         D          E
# 0          45  0.627228  0.639423  0.669767  56.000000
# 1    0.322129  0.409836  0.841431  0.727744   0.625058
# 2    0.078752  0.108694  0.514754  0.449441   0.141361
# 3    0.115186  0.443177  0.181930  0.464275   0.173529
# 4    0.002714  0.092858  0.635275  0.101599   0.671199
# ..        ...       ...       ...       ...        ...
# 329   0.65033  0.925719  0.660003  0.620706   0.684558
# 330    0.9935  0.269667  0.650373  0.724628   0.950385
# 331  0.444453  0.105023  0.840456  0.848208   0.550511
# 332  0.828512  0.593017  0.420084  0.204303   0.900175
# 333  0.068908  0.709423  0.464158  0.180856   0.270479
#
# [334 rows x 5 columns]

# %%
newdf.drop(['A', 'C'], axis = 1)
# Out:
#             B         D          E
# 0    0.627228  0.669767  56.000000
# 1    0.409836  0.727744   0.625058
# 2    0.108694  0.449441   0.141361
# 3    0.443177  0.464275   0.173529
# 4    0.092858  0.101599   0.671199
# ..        ...       ...        ...
# 329  0.925719  0.620706   0.684558
# 330  0.269667  0.724628   0.950385
# 331  0.105023  0.848208   0.550511
# 332  0.593017  0.204303   0.900175
# 333  0.709423  0.180856   0.270479
#
# [334 rows x 3 columns]

# %%
# By default axis = 0 rahta hai
newdf.drop([0,1,3])
# Out:
#             A         B         C         D         E
# 2    0.078752  0.108694  0.514754  0.449441  0.141361
# 4    0.002714  0.092858  0.635275  0.101599  0.671199
# 5     0.63215  0.714490  0.619169  0.869458  0.854780
# 6    0.964519  0.411591  0.948572  0.801621  0.723557
# 7    0.059238  0.914571  0.829711  0.487781  0.996982
# ..        ...       ...       ...       ...       ...
# 329   0.65033  0.925719  0.660003  0.620706  0.684558
# 330    0.9935  0.269667  0.650373  0.724628  0.950385
# 331  0.444453  0.105023  0.840456  0.848208  0.550511
# 332  0.828512  0.593017  0.420084  0.204303  0.900175
# 333  0.068908  0.709423  0.464158  0.180856  0.270479
#
# [331 rows x 5 columns]

# %%
# To drop a row in the same dataframe and make changes to the same dataframe, we use inplace = true
newdf.drop([0,1,3],axis = 0, inplace = True)

# %%
newdf
# Out:
#             A         B         C         D         E
# 2    0.078752  0.108694  0.514754  0.449441  0.141361
# 4    0.002714  0.092858  0.635275  0.101599  0.671199
# 5     0.63215  0.714490  0.619169  0.869458  0.854780
# 6    0.964519  0.411591  0.948572  0.801621  0.723557
# 7    0.059238  0.914571  0.829711  0.487781  0.996982
# ..        ...       ...       ...       ...       ...
# 329   0.65033  0.925719  0.660003  0.620706  0.684558
# 330    0.9935  0.269667  0.650373  0.724628  0.950385
# 331  0.444453  0.105023  0.840456  0.848208  0.550511
# 332  0.828512  0.593017  0.420084  0.204303  0.900175
# 333  0.068908  0.709423  0.464158  0.180856  0.270479
#
# [331 rows x 5 columns]

# %%
# To drop a column from the same dataframe and make changes to the original dataframe
newdf.drop(['A', 'C'], axis = 1, inplace = True)

# %%
newdf
# Out:
#             B         D         E
# 2    0.108694  0.449441  0.141361
# 4    0.092858  0.101599  0.671199
# 5    0.714490  0.869458  0.854780
# 6    0.411591  0.801621  0.723557
# 7    0.914571  0.487781  0.996982
# ..        ...       ...       ...
# 329  0.925719  0.620706  0.684558
# 330  0.269667  0.724628  0.950385
# 331  0.105023  0.848208  0.550511
# 332  0.593017  0.204303  0.900175
# 333  0.709423  0.180856  0.270479
#
# [331 rows x 3 columns]

# %%
newdf.head()
# Out:
#           B         D         E
# 2  0.108694  0.449441  0.141361
# 4  0.092858  0.101599  0.671199
# 5  0.714490  0.869458  0.854780
# 6  0.411591  0.801621  0.723557
# 7  0.914571  0.487781  0.996982

# %%
# We can reset the row name to start from 0, using reset_index() function
newdf.reset_index()
# Out:
#      index         B         D         E
# 0        2  0.108694  0.449441  0.141361
# 1        4  0.092858  0.101599  0.671199
# 2        5  0.714490  0.869458  0.854780
# 3        6  0.411591  0.801621  0.723557
# 4        7  0.914571  0.487781  0.996982
# ..     ...       ...       ...       ...
# 326    329  0.925719  0.620706  0.684558
# 327    330  0.269667  0.724628  0.950385
# 328    331  0.105023  0.848208  0.550511
# 329    332  0.593017  0.204303  0.900175
# 330    333  0.709423  0.180856  0.270479
#
# [331 rows x 4 columns]

# %%
# So, the problem of 2 index occurs , hence we write
newdf.reset_index(drop = True, inplace = True)

# %%
newdf
# Out:
#             B         D         E
# 0    0.108694  0.449441  0.141361
# 1    0.092858  0.101599  0.671199
# 2    0.714490  0.869458  0.854780
# 3    0.411591  0.801621  0.723557
# 4    0.914571  0.487781  0.996982
# ..        ...       ...       ...
# 326  0.925719  0.620706  0.684558
# 327  0.269667  0.724628  0.950385
# 328  0.105023  0.848208  0.550511
# 329  0.593017  0.204303  0.900175
# 330  0.709423  0.180856  0.270479
#
# [331 rows x 3 columns]

# %%
# It checks whether any row in B is empty or not
newdf.loc[ : , 'B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 326    False
# 327    False
# 328    False
# 329    False
# 330    False
# Name: B, Length: 331, dtype: bool

# %%
newdf.loc[ : , 'B'] = None

# %%
newdf
# Out:
#         B         D         E
# 0    None  0.449441  0.141361
# 1    None  0.101599  0.671199
# 2    None  0.869458  0.854780
# 3    None  0.801621  0.723557
# 4    None  0.487781  0.996982
# ..    ...       ...       ...
# 326  None  0.620706  0.684558
# 327  None  0.724628  0.950385
# 328  None  0.848208  0.550511
# 329  None  0.204303  0.900175
# 330  None  0.180856  0.270479
#
# [331 rows x 3 columns]

# %%
newdf.loc[ : , 'B'].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 326    True
# 327    True
# 328    True
# 329    True
# 330    True
# Name: B, Length: 331, dtype: bool

# %%
newdf.loc[ : , 'B'] = 34

# %%
newdf.head()
# Out:
#     B         D         E
# 0  34  0.449441  0.141361
# 1  34  0.101599  0.671199
# 2  34  0.869458  0.854780
# 3  34  0.801621  0.723557
# 4  34  0.487781  0.996982

# %%
df = pd.DataFrame({
    'name': ['Yum Yum', 'Yum Yum', np.nan, 'Indomie', 'Indomie'],
    'toy': ['cup', 'cup', 'cup', 'pack', np.nan ],
    'rating': [4, 4, 3.5, 15, 5]
})

# %%
df.head()
# Out:
#       name   toy  rating
# 0  Yum Yum   cup     4.0
# 1  Yum Yum   cup     4.0
# 2      NaN   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie   NaN     5.0

# %%
# Drops all rows which contains any na value
df.dropna()
# Out:
#       name   toy  rating
# 0  Yum Yum   cup     4.0
# 1  Yum Yum   cup     4.0
# 3  Indomie  pack    15.0

# %%
df.shape
# Out:
# (5, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   toy     4 non-null      object
#  2   rating  5 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 248.0+ bytes

# %%
# NA ko nahi count karega
df.loc[: , 'name'].value_counts(dropna = True)
# Out:
# Yum Yum    2
# Indomie    2
# Name: name, dtype: int64

# %%
df
# Out:
#       name   toy  rating
# 0  Yum Yum   cup     4.0
# 1  Yum Yum   cup     4.0
# 2      NaN   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie   NaN     5.0

# %%
df.notnull()
# Out:
#     name    toy  rating
# 0   True   True    True
# 1   True   True    True
# 2  False   True    True
# 3   True   True    True
# 4   True  False    True

# %%
dframe = pd.DataFrame(np.random.rand(3, 2))

# %%
dframe
# Out:
#           0         1
# 0  0.506052  0.083165
# 1  0.328319  0.724843
# 2  0.677184  0.216353

# %%
dframe.describe()
# Out:
#               0         1
# count  3.000000  3.000000
# mean   0.503852  0.341453
# std    0.174443  0.338637
# min    0.328319  0.083165
# 25%    0.417185  0.149759
# 50%    0.506052  0.216353
# 75%    0.591618  0.470598
# max    0.677184  0.724843

# %%
dframe.mean()
# Out:
# 0    0.503852
# 1    0.341453
# dtype: float64

# %%
dframe.count()
# Out:
# 0    3
# 1    3
# dtype: int64

# %%
dframe.corr()
# Out:
#           0         1
# 0  1.000000 -0.757959
# 1 -0.757959  1.000000

# %%
dframe.max()
# Out:
# 0    0.677184
# 1    0.724843
# dtype: float64

# %%
dframe.min()
# Out:
# 0    0.328319
# 1    0.083165
# dtype: float64

# %%
dframe.median()
# Out:
# 0    0.506052
# 1    0.216353
# dtype: float64

# %%
dframe.std()
# Out:
# 0    0.174443
# 1    0.338637
# dtype: float64

# %%
dframe2 = pd.read_excel('samplesafetydata.xlsx')

# %%
dframe2
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3      Unnamed: 4  Unnamed: 5  \
# 0   2020-01-01   Multiple       Male      25-34            Burn         0.0
# 1   2020-01-03        NaN       Male      35-49         Vehicle         0.5
# 2   2020-01-03        Eye       Male      18-24             Cut         0.0
# 3   2020-01-04       Legs     Female        50+  Falling object         0.0
# 4   2020-01-07       Legs       Male      25-34         Lifting         0.0
# ..         ...        ...        ...        ...             ...         ...
# 509 2022-06-26       Head     Female      25-34   Crush & Pinch         0.0
# 510 2022-06-27      Hands       Male      25-34         Lifting         0.0
# 511 2022-06-28      Hands       Male      25-34             Cut         0.0
# 512 2022-06-28      Trunk       Male        50+  Falling object         0.0
# 513 2022-06-28      Hands       Male      18-24         Vehicle         0.0
#
# ...
